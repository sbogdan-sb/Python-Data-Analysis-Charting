# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem
from matplotlib.ticker import PercentFormatter


# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_data_df = pd.read_csv(mouse_drug_data_to_load)
clinical_data_df = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_data_df, clinical_data_df, on = "Mouse ID")

# Display the data table for preview
merged_df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %%
#Clean the data

print(mouse_data_df["Mouse ID"].value_counts().head())

print(mouse_data_df[mouse_data_df["Mouse ID"] == 'g989']["Drug"])
# Out:
# g989    2
# w151    1
# x402    1
# o973    1
# q132    1
# Name: Mouse ID, dtype: int64
# 7      Stelasyn
# 173    Propriva
# Name: Drug, dtype: object

# %%
#Remove mouse g989 from data set since it was tested with 2 drugs
merged_df = merged_df[merged_df["Mouse ID"] != "g989"]

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
mean_tumor_vol = merged_df.groupby(["Drug", "Timepoint"]).mean()

# Convert to DataFrame
del mean_tumor_vol["Metastatic Sites"]
# Preview DataFrame
mean_tumor_vol.head(20)
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
#           25                  39.939528
#           30                  38.769339
#           35                  37.816839
#           40                  36.958001
#           45                  36.236114
# Ceftamin  0                   45.000000
#           5                   46.503051
#           10                  48.285125
#           15                  50.094055
#           20                  52.157049
#           25                  54.287674
#           30                  56.769517
#           35                  58.827548
#           40                  61.467895
#           45                  64.132421

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
mean_tumor_sem = merged_df.groupby(["Drug", "Timepoint"]).sem()

# Convert to DataFrame
del mean_tumor_sem["Metastatic Sites"]
# del mean_tumor_sem["Mouse ID"]

# Preview DataFrame
mean_tumor_sem.head(20)
# Out:
#                      Mouse ID  Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0               NaN            0.000000
#           5               NaN            0.448593
#           10              NaN            0.702684
#           15              NaN            0.838617
#           20              NaN            0.909731
#           25              NaN            0.881642
#           30              NaN            0.934460
#           35              NaN            1.052241
#           40              NaN            1.223608
#           45              NaN            1.223977
# Ceftamin  0               NaN            0.000000
#           5               NaN            0.164505
#           10              NaN            0.236144
#           15              NaN            0.332053
#           20              NaN            0.359482
#           25              NaN            0.439356
#           30              NaN            0.490620
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked
mean_tumor_vol_transposed = pd.pivot_table(mean_tumor_vol, index=["Timepoint", "Drug"]).unstack()
mean_tumor_vol_transposed.rename(columns = {'Tumor Volume (mm3)':''}, inplace = True)

mean_tumor_vol_transposed.head()
# Out:
#                                                                              \
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.168130  43.944859  47.470830  46.851818
# 10         48.938560  42.531957  49.335368  48.689881
# 15         50.891769  41.495061  51.448025  50.779059
# 20         53.127384  40.238325  53.970080  53.170334

# %%
mean_tumor_sem_transposed = pd.pivot_table(mean_tumor_sem, index=["Timepoint", "Drug"]).unstack()
mean_tumor_sem_transposed.rename(columns = {'Tumor Volume (mm3)':''}, inplace = True)
mean_tumor_sem_transposed.head(5)
# Out:
#                                                                        \
# Drug      Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5          0.448593  0.164505  0.235102  0.264819  0.202385  0.218091
# 10         0.702684  0.236144  0.282346  0.357421  0.319415  0.402064
# 15         0.838617  0.332053  0.357705  0.580268  0.444378  0.614461
# 20         0.909731  0.359482  0.476210  0.726484  0.595260  0.839609
#
#
# Drug       Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000
# 5          0.241842  0.482955  0.254830  0.188950
# 10         0.388701  0.720225  0.461474  0.263949
# 15         0.502024  0.770432  0.532904  0.370544
# 20         0.607412  0.786199  0.684670  0.533182

# %%
# fig, ax = plt.subplots()

count_chart = mean_tumor_vol_transposed.plot(kind = 'line', yerr = mean_tumor_sem_transposed,
                                            grid = True, figsize = (15,8), markersize = 10)


plt.xlabel("Time (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Response to Treatment")

legend_list = []
for i in mean_tumor_vol_transposed.columns.get_level_values(1):
    legend_list.append(i)
    

plt.legend(legend_list, ncol= 2, loc ='upper left', prop={'size': 15})

marker_list = ("o", "v", "s", "x", "P", "D", "H", "d", "*", ">")

for i, line in enumerate(count_chart.get_lines()):
    line.set_marker(marker_list[i])
    

plt.show()
type(count_chart)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
mean_metastatic = merged_df.groupby(["Drug", "Timepoint"]).mean()
del mean_metastatic["Tumor Volume (mm3)"]
mean_metastatic.head(20)
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174
#           25                 0.818182
#           30                 1.090909
#           35                 1.181818
#           40                 1.380952
#           45                 1.476190
# Ceftamin  0                  0.000000
#           5                  0.380952
#           10                 0.600000
#           15                 0.789474
#           20                 1.111111
#           25                 1.500000
#           30                 1.937500
#           35                 2.071429
#           40                 2.357143
#           45                 2.692308

# %%
mean_metastatic_sem = merged_df.groupby(["Drug", "Timepoint"]).sem()
del mean_metastatic_sem["Tumor Volume (mm3)"]
del mean_metastatic_sem["Mouse ID"]
mean_metastatic_sem.head(20)
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621
#           25                 0.181818
#           30                 0.172944
#           35                 0.169496
#           40                 0.175610
#           45                 0.202591
# Ceftamin  0                  0.000000
#           5                  0.108588
#           10                 0.152177
#           15                 0.180625
#           20                 0.241034
#           25                 0.258831
#           30                 0.249479
#           35                 0.266526
#           40                 0.289128
#           45                 0.286101

# %%
mean_metastatic_transposed = pd.pivot_table(mean_metastatic, index=["Timepoint", "Drug"]).unstack()
mean_metastatic_transposed.rename(columns = {"Metastatic Sites":''}, inplace = True)
mean_metastatic_transposed.head(5)
# Out:
#                                                                        \
# Drug      Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5          0.160000  0.380952  0.280000  0.304348  0.260870  0.375000
# 10         0.320000  0.600000  0.666667  0.590909  0.523810  0.833333
# 15         0.375000  0.789474  0.904762  0.842105  0.857143  1.250000
# 20         0.652174  1.111111  1.050000  1.210526  1.150000  1.526316
#
#
# Drug       Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000
# 5          0.347826  0.120000  0.260870  0.166667
# 10         0.619048  0.250000  0.523810  0.500000
# 15         0.800000  0.333333  0.809524  0.809524
# 20         1.000000  0.347826  0.947368  1.294118

# %%
mean_metastatic_sem_transposed = pd.pivot_table(mean_metastatic_sem, index=["Timepoint", "Drug"]).unstack()
mean_metastatic_sem_transposed.rename(columns = {"Metastatic Sites":''}, inplace = True)
mean_metastatic_sem_transposed.head(5)
# Out:
#                                                                        \
# Drug      Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5          0.074833  0.108588  0.091652  0.098100  0.093618  0.100947
# 10         0.125433  0.152177  0.159364  0.142018  0.163577  0.115261
# 15         0.132048  0.180625  0.194015  0.191381  0.158651  0.190221
# 20         0.161621  0.241034  0.234801  0.236680  0.181731  0.234064
#
#
# Drug       Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000
# 5          0.101543  0.066332  0.093618  0.077709
# 10         0.108588  0.090289  0.131277  0.109109
# 15         0.144749  0.115261  0.163577  0.111677
# 20         0.195180  0.119430  0.222607  0.166378

# %%
metastatic_chart = mean_metastatic_transposed.plot(kind = 'line', yerr = mean_metastatic_sem_transposed,
                                            grid = True, figsize = (15,8), markersize = 10)


plt.xlabel("Time (Days)")
plt.ylabel("Met. Sites")
plt.title("Metastatic Spread During Treatment")

legend_list = []
for i in mean_tumor_vol_transposed.columns.get_level_values(1):
    legend_list.append(i)
    

plt.legend(legend_list, ncol= 2, loc ='upper left', prop={'size': 15})

marker_list = ("o", "v", "s", "x", "P", "D", "H", "d", "*", ">")

for i, line in enumerate(metastatic_chart.get_lines()):
    line.set_marker(marker_list[i])
    

plt.show()

# %%
mouse_lifespan = merged_df.groupby(["Drug", "Timepoint"]).count()
del mouse_lifespan["Tumor Volume (mm3)"]
del mouse_lifespan["Metastatic Sites"]

mouse_lifespan
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23
#           25               22
#           30               22
#           35               22
#           40               21
#           45               21
# Ceftamin  0                25
#           5                21
#           10               20
#           15               19
#           20               18
#           25               18
#           30               16
#           35               14
#           40               14
#           45               13
# Infubinol 0                25
#           5                25
#           10               21
#           15               21
#           20               20
#           25               18
#           30               17
#           35               12
#           40               10
# ...

# %%
mouse_lifespan_transposed = pd.pivot_table(mouse_lifespan, index=["Timepoint", "Drug"]).unstack()
mouse_lifespan_transposed.rename(columns = {"Mouse ID": ""}, inplace = True)
mouse_lifespan_transposed.head(5)
# Out:
#                                                                            \
# Drug      Capomulin Ceftamin Infubinol Ketapril Naftisol Placebo Propriva
# Timepoint
# 0                25       25        25       25       25      25       24
# 5                25       21        25       23       23      24       23
# 10               25       20        21       22       21      24       21
# 15               24       19        21       19       21      20       15
# 20               23       18        20       19       20      19       15
#
#
# Drug      Ramicane Stelasyn Zoniferol
# Timepoint
# 0               25       24        25
# 5               25       23        24
# 10              24       21        22
# 15              24       21        21
# 20              23       19        17

# %%
lifespan_chart = mouse_lifespan_transposed.plot(kind = 'line', grid = True, figsize = (15,8), markersize = 10)


plt.xlabel("Time (Days)")
plt.ylabel("Met. Sites")
plt.title("Metastatic Spread During Treatment")

legend_list = []
for i in mean_tumor_vol_transposed.columns.get_level_values(1):
    legend_list.append(i)
    

plt.legend(legend_list, ncol= 2, loc ='lower left', prop={'size': 15})

marker_list = ("o", "v", "s", "x", "P", "D", "H", "d", "*", ">")

for i, line in enumerate(lifespan_chart.get_lines()):
    line.set_marker(marker_list[i])

plt.gca().yaxis.set_major_formatter(PercentFormatter(25))


plt.show()

# %%
mean_tumor_vol_transposed.columns.values

# %%
mean_tumor_vol_transposed.columns

# %%
legend_list = []
for i in mean_tumor_vol_transposed.columns.get_level_values(1):
    legend_list.append(i)
    print(i)
legend_list

mean_tumor_vol_transposed.columns.values
# Out:
# Capomulin
# Ceftamin
# Infubinol
# Ketapril
# Naftisol
# Placebo
# Propriva
# Ramicane
# Stelasyn
# Zoniferol
# array([('', 'Capomulin'), ('', 'Ceftamin'), ('', 'Infubinol'),
#        ('', 'Ketapril'), ('', 'Naftisol'), ('', 'Placebo'),
#        ('', 'Propriva'), ('', 'Ramicane'), ('', 'Stelasyn'),
#        ('', 'Zoniferol')], dtype=object)

# %%
mean_tumor_vol_transposed.columns.get_level_values(0)[2]

# %%
for row in mean_tumor_vol_transposed.iterrows():
    print(row[1][3])
